# %%
#Data Extraction for Inputs

import json
import os
import math
import librosa

DATASET_PATH = "E:\Data Science\genres"
JSON_PATH = "data_10.json"
SAMPLE_RATE = 22050
TRACK_DURATION = 30 # measured in seconds
SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION


def save_mfcc(dataset_path, json_path, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=5):
    """Extracts MFCCs from music dataset and saves them into a json file along witgh genre labels.
        :param dataset_path (str): Path to dataset
        :param json_path (str): Path to json file used to save MFCCs
        :param num_mfcc (int): Number of coefficients to extract
        :param n_fft (int): Interval we consider to apply FFT. Measured in # of samples
        :param hop_length (int): Sliding window for FFT. Measured in # of samples
        :param: num_segments (int): Number of segments we want to divide sample tracks into
        :return:
        """

    # dictionary to store mapping, labels, and MFCCs
    data = {
        "mapping": [],
        "labels": [],
        "mfcc": []
    }

    samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

    # loop through all genre sub-folder
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):

        # ensure we're processing a genre sub-folder level
        if dirpath is not dataset_path:

            # save genre label (i.e., sub-folder name) in the mapping
            semantic_label = dirpath.split("/")[-1]
            data["mapping"].append(semantic_label)
            print("\nProcessing: {}".format(semantic_label))

            # process all audio files in genre sub-dir
            for f in filenames:

		# load audio file
                file_path = os.path.join(dirpath, f)
                signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)

                # process all segments of audio file
                for d in range(num_segments):

                    # calculate start and finish sample for current segment
                    start = samples_per_segment * d
                    finish = start + samples_per_segment

                    # extract mfcc
                    mfcc = librosa.feature.mfcc(signal[start:finish], sample_rate, n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length)
                    mfcc = mfcc.T

                    # store only mfcc feature with expected number of vectors
                    if len(mfcc) == num_mfcc_vectors_per_segment:
                        data["mfcc"].append(mfcc.tolist())
                        data["labels"].append(i-1)
                        print("{}, segment:{}".format(file_path, d+1))

    # save MFCCs to json file
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)
        
        
if __name__ == "__main__":
    save_mfcc(DATASET_PATH, JSON_PATH, num_segments=10)
# Out:
# Processing: E:\Data Science\genres\blues
# E:\Data Science\genres\blues\blues.00000.wav, segment:1
# E:\Data Science\genres\blues\blues.00000.wav, segment:2
# E:\Data Science\genres\blues\blues.00000.wav, segment:3
# E:\Data Science\genres\blues\blues.00000.wav, segment:4
# E:\Data Science\genres\blues\blues.00000.wav, segment:5
# E:\Data Science\genres\blues\blues.00000.wav, segment:6
# E:\Data Science\genres\blues\blues.00000.wav, segment:7
# E:\Data Science\genres\blues\blues.00000.wav, segment:8
# E:\Data Science\genres\blues\blues.00000.wav, segment:9
# E:\Data Science\genres\blues\blues.00000.wav, segment:10
# E:\Data Science\genres\blues\blues.00001.wav, segment:1
# E:\Data Science\genres\blues\blues.00001.wav, segment:2
# E:\Data Science\genres\blues\blues.00001.wav, segment:3
# E:\Data Science\genres\blues\blues.00001.wav, segment:4
# E:\Data Science\genres\blues\blues.00001.wav, segment:5
# E:\Data Science\genres\blues\blues.00001.wav, segment:6
# E:\Data Science\genres\blues\blues.00001.wav, segment:7
# E:\Data Science\genres\blues\blues.00001.wav, segment:8
# E:\Data Science\genres\blues\blues.00001.wav, segment:9
# E:\Data Science\genres\blues\blues.00001.wav, segment:10
# E:\Data Science\genres\blues\blues.00002.wav, segment:1
# E:\Data Science\genres\blues\blues.00002.wav, segment:2
# E:\Data Science\genres\blues\blues.00002.wav, segment:3
# E:\Data Science\genres\blues\blues.00002.wav, segment:4
# E:\Data Science\genres\blues\blues.00002.wav, segment:5
# E:\Data Science\genres\blues\blues.00002.wav, segment:6
# E:\Data Science\genres\blues\blues.00002.wav, segment:7
# E:\Data Science\genres\blues\blues.00002.wav, segment:8
# E:\Data Science\genres\blues\blues.00002.wav, segment:9
# E:\Data Science\genres\blues\blues.00002.wav, segment:10
# E:\Data Science\genres\blues\blues.00003.wav, segment:1
# E:\Data Science\genres\blues\blues.00003.wav, segment:2
# E:\Data Science\genres\blues\blues.00003.wav, segment:3
# E:\Data Science\genres\blues\blues.00003.wav, segment:4
# E:\Data Science\genres\blues\blues.00003.wav, segment:5
# E:\Data Science\genres\blues\blues.00003.wav, segment:6
# E:\Data Science\genres\blues\blues.00003.wav, segment:7
# E:\Data Science\genres\blues\blues.00003.wav, segment:8
# E:\Data Science\genres\blues\blues.00003.wav, segment:9
# E:\Data Science\genres\blues\blues.00003.wav, segment:10
# E:\Data Science\genres\blues\blues.00004.wav, segment:1
# E:\Data Science\genres\blues\blues.00004.wav, segment:2
# E:\Data Science\genres\blues\blues.00004.wav, segment:3
# E:\Data Science\genres\blues\blues.00004.wav, segment:4
# E:\Data Science\genres\blues\blues.00004.wav, segment:5
# E:\Data Science\genres\blues\blues.00004.wav, segment:6
# E:\Data Science\genres\blues\blues.00004.wav, segment:7
# E:\Data Science\genres\blues\blues.00004.wav, segment:8
# E:\Data Science\genres\blues\blues.00004.wav, segment:9
# E:\Data Science\genres\blues\blues.00004.wav, segment:10
# E:\Data Science\genres\blues\blues.00005.wav, segment:1
# E:\Data Science\genres\blues\blues.00005.wav, segment:2
# E:\Data Science\genres\blues\blues.00005.wav, segment:3
# E:\Data Science\genres\blues\blues.00005.wav, segment:4
# E:\Data Science\genres\blues\blues.00005.wav, segment:5
# E:\Data Science\genres\blues\blues.00005.wav, segment:6
# E:\Data Science\genres\blues\blues.00005.wav, segment:7
# E:\Data Science\genres\blues\blues.00005.wav, segment:8
# E:\Data Science\genres\blues\blues.00005.wav, segment:9
# E:\Data Science\genres\blues\blues.00005.wav, segment:10
# E:\Data Science\genres\blues\blues.00006.wav, segment:1
# E:\Data Science\genres\blues\blues.00006.wav, segment:2
# E:\Data Science\genres\blues\blues.00006.wav, segment:3
# E:\Data Science\genres\blues\blues.00006.wav, segment:4
# E:\Data Science\genres\blues\blues.00006.wav, segment:5
# E:\Data Science\genres\blues\blues.00006.wav, segment:6
# E:\Data Science\genres\blues\blues.00006.wav, segment:7
# E:\Data Science\genres\blues\blues.00006.wav, segment:8
# E:\Data Science\genres\blues\blues.00006.wav, segment:9
# E:\Data Science\genres\blues\blues.00006.wav, segment:10
# E:\Data Science\genres\blues\blues.00007.wav, segment:1
# E:\Data Science\genres\blues\blues.00007.wav, segment:2
# E:\Data Science\genres\blues\blues.00007.wav, segment:3
# E:\Data Science\genres\blues\blues.00007.wav, segment:4
# E:\Data Science\genres\blues\blues.00007.wav, segment:5
# E:\Data Science\genres\blues\blues.00007.wav, segment:6
# E:\Data Science\genres\blues\blues.00007.wav, segment:7
# E:\Data Science\genres\blues\blues.00007.wav, segment:8
# E:\Data Science\genres\blues\blues.00007.wav, segment:9
# E:\Data Science\genres\blues\blues.00007.wav, segment:10
# E:\Data Science\genres\blues\blues.00008.wav, segment:1
# E:\Data Science\genres\blues\blues.00008.wav, segment:2
# E:\Data Science\genres\blues\blues.00008.wav, segment:3
# E:\Data Science\genres\blues\blues.00008.wav, segment:4
# E:\Data Science\genres\blues\blues.00008.wav, segment:5
# E:\Data Science\genres\blues\blues.00008.wav, segment:6
# E:\Data Science\genres\blues\blues.00008.wav, segment:7
# E:\Data Science\genres\blues\blues.00008.wav, segment:8
# E:\Data Science\genres\blues\blues.00008.wav, segment:9
# E:\Data Science\genres\blues\blues.00008.wav, segment:10
# E:\Data Science\genres\blues\blues.00009.wav, segment:1
# E:\Data Science\genres\blues\blues.00009.wav, segment:2
# E:\Data Science\genres\blues\blues.00009.wav, segment:3
# E:\Data Science\genres\blues\blues.00009.wav, segment:4
# E:\Data Science\genres\blues\blues.00009.wav, segment:5
# E:\Data Science\genres\blues\blues.00009.wav, segment:6
# E:\Data Science\genres\blues\blues.00009.wav, segment:7
# E:\Data Science\genres\blues\blues.00009.wav, segment:8
# E:\Data Science\genres\blues\blues.00009.wav, segment:9
# E:\Data Science\genres\blues\blues.00009.wav, segment:10
# E:\Data Science\genres\blues\blues.00010.wav, segment:1
# E:\Data Science\genres\blues\blues.00010.wav, segment:2
# E:\Data Science\genres\blues\blues.00010.wav, segment:3
# E:\Data Science\genres\blues\blues.00010.wav, segment:4
# E:\Data Science\genres\blues\blues.00010.wav, segment:5
# E:\Data Science\genres\blues\blues.00010.wav, segment:6
# E:\Data Science\genres\blues\blues.00010.wav, segment:7
# E:\Data Science\genres\blues\blues.00010.wav, segment:8
# E:\Data Science\genres\blues\blues.00010.wav, segment:9
# E:\Data Science\genres\blues\blues.00010.wav, segment:10
# E:\Data Science\genres\blues\blues.00011.wav, segment:1
# E:\Data Science\genres\blues\blues.00011.wav, segment:2
# E:\Data Science\genres\blues\blues.00011.wav, segment:3
# E:\Data Science\genres\blues\blues.00011.wav, segment:4
# E:\Data Science\genres\blues\blues.00011.wav, segment:5
# E:\Data Science\genres\blues\blues.00011.wav, segment:6
# E:\Data Science\genres\blues\blues.00011.wav, segment:7
# E:\Data Science\genres\blues\blues.00011.wav, segment:8
# E:\Data Science\genres\blues\blues.00011.wav, segment:9
# E:\Data Science\genres\blues\blues.00011.wav, segment:10
# E:\Data Science\genres\blues\blues.00012.wav, segment:1
# E:\Data Science\genres\blues\blues.00012.wav, segment:2
# E:\Data Science\genres\blues\blues.00012.wav, segment:3
# E:\Data Science\genres\blues\blues.00012.wav, segment:4
# E:\Data Science\genres\blues\blues.00012.wav, segment:5
# E:\Data Science\genres\blues\blues.00012.wav, segment:6
# E:\Data Science\genres\blues\blues.00012.wav, segment:7
# E:\Data Science\genres\blues\blues.00012.wav, segment:8
# E:\Data Science\genres\blues\blues.00012.wav, segment:9
# E:\Data Science\genres\blues\blues.00012.wav, segment:10
# E:\Data Science\genres\blues\blues.00013.wav, segment:1
# E:\Data Science\genres\blues\blues.00013.wav, segment:2
# E:\Data Science\genres\blues\blues.00013.wav, segment:3
# E:\Data Science\genres\blues\blues.00013.wav, segment:4
# E:\Data Science\genres\blues\blues.00013.wav, segment:5
# E:\Data Science\genres\blues\blues.00013.wav, segment:6
# E:\Data Science\genres\blues\blues.00013.wav, segment:7
# E:\Data Science\genres\blues\blues.00013.wav, segment:8
# E:\Data Science\genres\blues\blues.00013.wav, segment:9
# E:\Data Science\genres\blues\blues.00013.wav, segment:10
# E:\Data Science\genres\blues\blues.00014.wav, segment:1
# E:\Data Science\genres\blues\blues.00014.wav, segment:2
# E:\Data Science\genres\blues\blues.00014.wav, segment:3
# E:\Data Science\genres\blues\blues.00014.wav, segment:4
# E:\Data Science\genres\blues\blues.00014.wav, segment:5
# E:\Data Science\genres\blues\blues.00014.wav, segment:6
# E:\Data Science\genres\blues\blues.00014.wav, segment:7
# E:\Data Science\genres\blues\blues.00014.wav, segment:8
# E:\Data Science\genres\blues\blues.00014.wav, segment:9
# E:\Data Science\genres\blues\blues.00014.wav, segment:10
# E:\Data Science\genres\blues\blues.00015.wav, segment:1
# E:\Data Science\genres\blues\blues.00015.wav, segment:2
# E:\Data Science\genres\blues\blues.00015.wav, segment:3
# E:\Data Science\genres\blues\blues.00015.wav, segment:4
# E:\Data Science\genres\blues\blues.00015.wav, segment:5
# E:\Data Science\genres\blues\blues.00015.wav, segment:6
# E:\Data Science\genres\blues\blues.00015.wav, segment:7
# E:\Data Science\genres\blues\blues.00015.wav, segment:8
# E:\Data Science\genres\blues\blues.00015.wav, segment:9
# E:\Data Science\genres\blues\blues.00015.wav, segment:10
# E:\Data Science\genres\blues\blues.00016.wav, segment:1
# E:\Data Science\genres\blues\blues.00016.wav, segment:2
# E:\Data Science\genres\blues\blues.00016.wav, segment:3
# E:\Data Science\genres\blues\blues.00016.wav, segment:4
# E:\Data Science\genres\blues\blues.00016.wav, segment:5
# E:\Data Science\genres\blues\blues.00016.wav, segment:6
# E:\Data Science\genres\blues\blues.00016.wav, segment:7
# E:\Data Science\genres\blues\blues.00016.wav, segment:8
# E:\Data Science\genres\blues\blues.00016.wav, segment:9
# E:\Data Science\genres\blues\blues.00016.wav, segment:10
# E:\Data Science\genres\blues\blues.00017.wav, segment:1
# E:\Data Science\genres\blues\blues.00017.wav, segment:2
# E:\Data Science\genres\blues\blues.00017.wav, segment:3
# E:\Data Science\genres\blues\blues.00017.wav, segment:4
# E:\Data Science\genres\blues\blues.00017.wav, segment:5
# E:\Data Science\genres\blues\blues.00017.wav, segment:6
# E:\Data Science\genres\blues\blues.00017.wav, segment:7
# E:\Data Science\genres\blues\blues.00017.wav, segment:8
# E:\Data Science\genres\blues\blues.00017.wav, segment:9
# E:\Data Science\genres\blues\blues.00017.wav, segment:10
# E:\Data Science\genres\blues\blues.00018.wav, segment:1
# E:\Data Science\genres\blues\blues.00018.wav, segment:2
# E:\Data Science\genres\blues\blues.00018.wav, segment:3
# E:\Data Science\genres\blues\blues.00018.wav, segment:4
# E:\Data Science\genres\blues\blues.00018.wav, segment:5
# E:\Data Science\genres\blues\blues.00018.wav, segment:6
# E:\Data Science\genres\blues\blues.00018.wav, segment:7
# E:\Data Science\genres\blues\blues.00018.wav, segment:8
# E:\Data Science\genres\blues\blues.00018.wav, segment:9
# E:\Data Science\genres\blues\blues.00018.wav, segment:10
# E:\Data Science\genres\blues\blues.00019.wav, segment:1
# E:\Data Science\genres\blues\blues.00019.wav, segment:2
# E:\Data Science\genres\blues\blues.00019.wav, segment:3
# E:\Data Science\genres\blues\blues.00019.wav, segment:4
# E:\Data Science\genres\blues\blues.00019.wav, segment:5
# E:\Data Science\genres\blues\blues.00019.wav, segment:6
# E:\Data Science\genres\blues\blues.00019.wav, segment:7
# E:\Data Science\genres\blues\blues.00019.wav, segment:8
# E:\Data Science\genres\blues\blues.00019.wav, segment:9
# E:\Data Science\genres\blues\blues.00019.wav, segment:10
# E:\Data Science\genres\blues\blues.00020.wav, segment:1
# E:\Data Science\genres\blues\blues.00020.wav, segment:2
# E:\Data Science\genres\blues\blues.00020.wav, segment:3
# E:\Data Science\genres\blues\blues.00020.wav, segment:4
# E:\Data Science\genres\blues\blues.00020.wav, segment:5
# E:\Data Science\genres\blues\blues.00020.wav, segment:6
# E:\Data Science\genres\blues\blues.00020.wav, segment:7
# E:\Data Science\genres\blues\blues.00020.wav, segment:8
# E:\Data Science\genres\blues\blues.00020.wav, segment:9
# E:\Data Science\genres\blues\blues.00020.wav, segment:10
# E:\Data Science\genres\blues\blues.00021.wav, segment:1
# E:\Data Science\genres\blues\blues.00021.wav, segment:2
# E:\Data Science\genres\blues\blues.00021.wav, segment:3
# E:\Data Science\genres\blues\blues.00021.wav, segment:4
# E:\Data Science\genres\blues\blues.00021.wav, segment:5
# E:\Data Science\genres\blues\blues.00021.wav, segment:6
# E:\Data Science\genres\blues\blues.00021.wav, segment:7
# E:\Data Science\genres\blues\blues.00021.wav, segment:8
# E:\Data Science\genres\blues\blues.00021.wav, segment:9
# E:\Data Science\genres\blues\blues.00021.wav, segment:10
# E:\Data Science\genres\blues\blues.00022.wav, segment:1
# E:\Data Science\genres\blues\blues.00022.wav, segment:2
# E:\Data Science\genres\blues\blues.00022.wav, segment:3
# E:\Data Science\genres\blues\blues.00022.wav, segment:4
# E:\Data Science\genres\blues\blues.00022.wav, segment:5
# E:\Data Science\genres\blues\blues.00022.wav, segment:6
# E:\Data Science\genres\blues\blues.00022.wav, segment:7
# E:\Data Science\genres\blues\blues.00022.wav, segment:8
# E:\Data Science\genres\blues\blues.00022.wav, segment:9
# E:\Data Science\genres\blues\blues.00022.wav, segment:10
# E:\Data Science\genres\blues\blues.00023.wav, segment:1
# E:\Data Science\genres\blues\blues.00023.wav, segment:2
# E:\Data Science\genres\blues\blues.00023.wav, segment:3
# E:\Data Science\genres\blues\blues.00023.wav, segment:4
# E:\Data Science\genres\blues\blues.00023.wav, segment:5
# E:\Data Science\genres\blues\blues.00023.wav, segment:6
# E:\Data Science\genres\blues\blues.00023.wav, segment:7
# E:\Data Science\genres\blues\blues.00023.wav, segment:8
# E:\Data Science\genres\blues\blues.00023.wav, segment:9
# E:\Data Science\genres\blues\blues.00023.wav, segment:10
# E:\Data Science\genres\blues\blues.00024.wav, segment:1
# E:\Data Science\genres\blues\blues.00024.wav, segment:2
# E:\Data Science\genres\blues\blues.00024.wav, segment:3
# E:\Data Science\genres\blues\blues.00024.wav, segment:4
# E:\Data Science\genres\blues\blues.00024.wav, segment:5
# E:\Data Science\genres\blues\blues.00024.wav, segment:6
# E:\Data Science\genres\blues\blues.00024.wav, segment:7
# E:\Data Science\genres\blues\blues.00024.wav, segment:8
# E:\Data Science\genres\blues\blues.00024.wav, segment:9
# E:\Data Science\genres\blues\blues.00024.wav, segment:10
# E:\Data Science\genres\blues\blues.00025.wav, segment:1
# E:\Data Science\genres\blues\blues.00025.wav, segment:2
# E:\Data Science\genres\blues\blues.00025.wav, segment:3
# E:\Data Science\genres\blues\blues.00025.wav, segment:4
# E:\Data Science\genres\blues\blues.00025.wav, segment:5
# E:\Data Science\genres\blues\blues.00025.wav, segment:6
# E:\Data Science\genres\blues\blues.00025.wav, segment:7
# E:\Data Science\genres\blues\blues.00025.wav, segment:8
# E:\Data Science\genres\blues\blues.00025.wav, segment:9
# E:\Data Science\genres\blues\blues.00025.wav, segment:10
# E:\Data Science\genres\blues\blues.00026.wav, segment:1
# E:\Data Science\genres\blues\blues.00026.wav, segment:2
# E:\Data Science\genres\blues\blues.00026.wav, segment:3
# E:\Data Science\genres\blues\blues.00026.wav, segment:4
# E:\Data Science\genres\blues\blues.00026.wav, segment:5
# E:\Data Science\genres\blues\blues.00026.wav, segment:6
# E:\Data Science\genres\blues\blues.00026.wav, segment:7
# E:\Data Science\genres\blues\blues.00026.wav, segment:8
# E:\Data Science\genres\blues\blues.00026.wav, segment:9
# E:\Data Science\genres\blues\blues.00026.wav, segment:10
# E:\Data Science\genres\blues\blues.00027.wav, segment:1
# E:\Data Science\genres\blues\blues.00027.wav, segment:2
# E:\Data Science\genres\blues\blues.00027.wav, segment:3
# E:\Data Science\genres\blues\blues.00027.wav, segment:4
# E:\Data Science\genres\blues\blues.00027.wav, segment:5
# E:\Data Science\genres\blues\blues.00027.wav, segment:6
# E:\Data Science\genres\blues\blues.00027.wav, segment:7
# E:\Data Science\genres\blues\blues.00027.wav, segment:8
# E:\Data Science\genres\blues\blues.00027.wav, segment:9
# E:\Data Science\genres\blues\blues.00027.wav, segment:10
# E:\Data Science\genres\blues\blues.00028.wav, segment:1
# E:\Data Science\genres\blues\blues.00028.wav, segment:2
# E:\Data Science\genres\blues\blues.00028.wav, segment:3
# E:\Data Science\genres\blues\blues.00028.wav, segment:4
# E:\Data Science\genres\blues\blues.00028.wav, segment:5
# E:\Data Science\genres\blues\blues.00028.wav, segment:6
# E:\Data Science\genres\blues\blues.00028.wav, segment:7
# E:\Data Science\genres\blues\blues.00028.wav, segment:8
# E:\Data Science\genres\blues\blues.00028.wav, segment:9
# E:\Data Science\genres\blues\blues.00028.wav, segment:10
# E:\Data Science\genres\blues\blues.00029.wav, segment:1
# E:\Data Science\genres\blues\blues.00029.wav, segment:2
# E:\Data Science\genres\blues\blues.00029.wav, segment:3
# E:\Data Science\genres\blues\blues.00029.wav, segment:4
# E:\Data Science\genres\blues\blues.00029.wav, segment:5
# E:\Data Science\genres\blues\blues.00029.wav, segment:6
# E:\Data Science\genres\blues\blues.00029.wav, segment:7
# E:\Data Science\genres\blues\blues.00029.wav, segment:8
# E:\Data Science\genres\blues\blues.00029.wav, segment:9
# E:\Data Science\genres\blues\blues.00029.wav, segment:10
# E:\Data Science\genres\blues\blues.00030.wav, segment:1
# E:\Data Science\genres\blues\blues.00030.wav, segment:2
# E:\Data Science\genres\blues\blues.00030.wav, segment:3
# E:\Data Science\genres\blues\blues.00030.wav, segment:4
# E:\Data Science\genres\blues\blues.00030.wav, segment:5
# E:\Data Science\genres\blues\blues.00030.wav, segment:6
# E:\Data Science\genres\blues\blues.00030.wav, segment:7
# E:\Data Science\genres\blues\blues.00030.wav, segment:8
# E:\Data Science\genres\blues\blues.00030.wav, segment:9
# E:\Data Science\genres\blues\blues.00030.wav, segment:10
# E:\Data Science\genres\blues\blues.00031.wav, segment:1
# E:\Data Science\genres\blues\blues.00031.wav, segment:2
# E:\Data Science\genres\blues\blues.00031.wav, segment:3
# E:\Data Science\genres\blues\blues.00031.wav, segment:4
# E:\Data Science\genres\blues\blues.00031.wav, segment:5
# E:\Data Science\genres\blues\blues.00031.wav, segment:6
# E:\Data Science\genres\blues\blues.00031.wav, segment:7
# E:\Data Science\genres\blues\blues.00031.wav, segment:8
# E:\Data Science\genres\blues\blues.00031.wav, segment:9
# E:\Data Science\genres\blues\blues.00031.wav, segment:10
# E:\Data Science\genres\blues\blues.00032.wav, segment:1
# E:\Data Science\genres\blues\blues.00032.wav, segment:2
# E:\Data Science\genres\blues\blues.00032.wav, segment:3
# E:\Data Science\genres\blues\blues.00032.wav, segment:4
# E:\Data Science\genres\blues\blues.00032.wav, segment:5
# E:\Data Science\genres\blues\blues.00032.wav, segment:6
# E:\Data Science\genres\blues\blues.00032.wav, segment:7
# E:\Data Science\genres\blues\blues.00032.wav, segment:8
# E:\Data Science\genres\blues\blues.00032.wav, segment:9
# E:\Data Science\genres\blues\blues.00032.wav, segment:10
# E:\Data Science\genres\blues\blues.00033.wav, segment:1
# E:\Data Science\genres\blues\blues.00033.wav, segment:2
# E:\Data Science\genres\blues\blues.00033.wav, segment:3
# E:\Data Science\genres\blues\blues.00033.wav, segment:4
# E:\Data Science\genres\blues\blues.00033.wav, segment:5
# E:\Data Science\genres\blues\blues.00033.wav, segment:6
# E:\Data Science\genres\blues\blues.00033.wav, segment:7
# E:\Data Science\genres\blues\blues.00033.wav, segment:8
# E:\Data Science\genres\blues\blues.00033.wav, segment:9
# E:\Data Science\genres\blues\blues.00033.wav, segment:10
# E:\Data Science\genres\blues\blues.00034.wav, segment:1
# E:\Data Science\genres\blues\blues.00034.wav, segment:2
# E:\Data Science\genres\blues\blues.00034.wav, segment:3
# E:\Data Science\genres\blues\blues.00034.wav, segment:4
# E:\Data Science\genres\blues\blues.00034.wav, segment:5
# E:\Data Science\genres\blues\blues.00034.wav, segment:6
# E:\Data Science\genres\blues\blues.00034.wav, segment:7
# E:\Data Science\genres\blues\blues.00034.wav, segment:8
# E:\Data Science\genres\blues\blues.00034.wav, segment:9
# E:\Data Science\genres\blues\blues.00034.wav, segment:10
# E:\Data Science\genres\blues\blues.00035.wav, segment:1
# E:\Data Science\genres\blues\blues.00035.wav, segment:2
# E:\Data Science\genres\blues\blues.00035.wav, segment:3
# E:\Data Science\genres\blues\blues.00035.wav, segment:4
# E:\Data Science\genres\blues\blues.00035.wav, segment:5
# E:\Data Science\genres\blues\blues.00035.wav, segment:6
# E:\Data Science\genres\blues\blues.00035.wav, segment:7
# E:\Data Science\genres\blues\blues.00035.wav, segment:8
# E:\Data Science\genres\blues\blues.00035.wav, segment:9
# E:\Data Science\genres\blues\blues.00035.wav, segment:10
# E:\Data Science\genres\blues\blues.00036.wav, segment:1
# E:\Data Science\genres\blues\blues.00036.wav, segment:2
# E:\Data Science\genres\blues\blues.00036.wav, segment:3
# E:\Data Science\genres\blues\blues.00036.wav, segment:4
# E:\Data Science\genres\blues\blues.00036.wav, segment:5
# E:\Data Science\genres\blues\blues.00036.wav, segment:6
# E:\Data Science\genres\blues\blues.00036.wav, segment:7
# E:\Data Science\genres\blues\blues.00036.wav, segment:8
# E:\Data Science\genres\blues\blues.00036.wav, segment:9
# E:\Data Science\genres\blues\blues.00036.wav, segment:10
# E:\Data Science\genres\blues\blues.00037.wav, segment:1
# E:\Data Science\genres\blues\blues.00037.wav, segment:2
# E:\Data Science\genres\blues\blues.00037.wav, segment:3
# E:\Data Science\genres\blues\blues.00037.wav, segment:4
# E:\Data Science\genres\blues\blues.00037.wav, segment:5
# E:\Data Science\genres\blues\blues.00037.wav, segment:6
# E:\Data Science\genres\blues\blues.00037.wav, segment:7
# E:\Data Science\genres\blues\blues.00037.wav, segment:8
# E:\Data Science\genres\blues\blues.00037.wav, segment:9
# E:\Data Science\genres\blues\blues.00037.wav, segment:10
# E:\Data Science\genres\blues\blues.00038.wav, segment:1
# E:\Data Science\genres\blues\blues.00038.wav, segment:2
# E:\Data Science\genres\blues\blues.00038.wav, segment:3
# E:\Data Science\genres\blues\blues.00038.wav, segment:4
# E:\Data Science\genres\blues\blues.00038.wav, segment:5
# E:\Data Science\genres\blues\blues.00038.wav, segment:6
# E:\Data Science\genres\blues\blues.00038.wav, segment:7
# E:\Data Science\genres\blues\blues.00038.wav, segment:8
# E:\Data Science\genres\blues\blues.00038.wav, segment:9
# E:\Data Science\genres\blues\blues.00038.wav, segment:10
# E:\Data Science\genres\blues\blues.00039.wav, segment:1
# E:\Data Science\genres\blues\blues.00039.wav, segment:2
# E:\Data Science\genres\blues\blues.00039.wav, segment:3
# E:\Data Science\genres\blues\blues.00039.wav, segment:4
# E:\Data Science\genres\blues\blues.00039.wav, segment:5
# E:\Data Science\genres\blues\blues.00039.wav, segment:6
# E:\Data Science\genres\blues\blues.00039.wav, segment:7
# E:\Data Science\genres\blues\blues.00039.wav, segment:8
# E:\Data Science\genres\blues\blues.00039.wav, segment:9
# E:\Data Science\genres\blues\blues.00039.wav, segment:10
# E:\Data Science\genres\blues\blues.00040.wav, segment:1
# E:\Data Science\genres\blues\blues.00040.wav, segment:2
# E:\Data Science\genres\blues\blues.00040.wav, segment:3
# E:\Data Science\genres\blues\blues.00040.wav, segment:4
# E:\Data Science\genres\blues\blues.00040.wav, segment:5
# E:\Data Science\genres\blues\blues.00040.wav, segment:6
# E:\Data Science\genres\blues\blues.00040.wav, segment:7
# E:\Data Science\genres\blues\blues.00040.wav, segment:8
# E:\Data Science\genres\blues\blues.00040.wav, segment:9
# E:\Data Science\genres\blues\blues.00040.wav, segment:10
# E:\Data Science\genres\blues\blues.00041.wav, segment:1
# E:\Data Science\genres\blues\blues.00041.wav, segment:2
# E:\Data Science\genres\blues\blues.00041.wav, segment:3
# E:\Data Science\genres\blues\blues.00041.wav, segment:4
# E:\Data Science\genres\blues\blues.00041.wav, segment:5
# E:\Data Science\genres\blues\blues.00041.wav, segment:6
# E:\Data Science\genres\blues\blues.00041.wav, segment:7
# E:\Data Science\genres\blues\blues.00041.wav, segment:8
# E:\Data Science\genres\blues\blues.00041.wav, segment:9
# E:\Data Science\genres\blues\blues.00041.wav, segment:10
# E:\Data Science\genres\blues\blues.00042.wav, segment:1
# E:\Data Science\genres\blues\blues.00042.wav, segment:2
# E:\Data Science\genres\blues\blues.00042.wav, segment:3
# E:\Data Science\genres\blues\blues.00042.wav, segment:4
# E:\Data Science\genres\blues\blues.00042.wav, segment:5
# E:\Data Science\genres\blues\blues.00042.wav, segment:6
# E:\Data Science\genres\blues\blues.00042.wav, segment:7
# E:\Data Science\genres\blues\blues.00042.wav, segment:8
# E:\Data Science\genres\blues\blues.00042.wav, segment:9
# E:\Data Science\genres\blues\blues.00042.wav, segment:10
# E:\Data Science\genres\blues\blues.00043.wav, segment:1
# E:\Data Science\genres\blues\blues.00043.wav, segment:2
# E:\Data Science\genres\blues\blues.00043.wav, segment:3
# E:\Data Science\genres\blues\blues.00043.wav, segment:4
# E:\Data Science\genres\blues\blues.00043.wav, segment:5
# E:\Data Science\genres\blues\blues.00043.wav, segment:6
# E:\Data Science\genres\blues\blues.00043.wav, segment:7
# E:\Data Science\genres\blues\blues.00043.wav, segment:8
# E:\Data Science\genres\blues\blues.00043.wav, segment:9
# E:\Data Science\genres\blues\blues.00043.wav, segment:10
# E:\Data Science\genres\blues\blues.00044.wav, segment:1
# E:\Data Science\genres\blues\blues.00044.wav, segment:2
# E:\Data Science\genres\blues\blues.00044.wav, segment:3
# E:\Data Science\genres\blues\blues.00044.wav, segment:4
# E:\Data Science\genres\blues\blues.00044.wav, segment:5
# E:\Data Science\genres\blues\blues.00044.wav, segment:6
# E:\Data Science\genres\blues\blues.00044.wav, segment:7
# E:\Data Science\genres\blues\blues.00044.wav, segment:8
# E:\Data Science\genres\blues\blues.00044.wav, segment:9
# E:\Data Science\genres\blues\blues.00044.wav, segment:10
# E:\Data Science\genres\blues\blues.00045.wav, segment:1
# E:\Data Science\genres\blues\blues.00045.wav, segment:2
# E:\Data Science\genres\blues\blues.00045.wav, segment:3
# E:\Data Science\genres\blues\blues.00045.wav, segment:4
# E:\Data Science\genres\blues\blues.00045.wav, segment:5
# E:\Data Science\genres\blues\blues.00045.wav, segment:6
# E:\Data Science\genres\blues\blues.00045.wav, segment:7
# E:\Data Science\genres\blues\blues.00045.wav, segment:8
# E:\Data Science\genres\blues\blues.00045.wav, segment:9
# E:\Data Science\genres\blues\blues.00045.wav, segment:10
# E:\Data Science\genres\blues\blues.00046.wav, segment:1
# E:\Data Science\genres\blues\blues.00046.wav, segment:2
# E:\Data Science\genres\blues\blues.00046.wav, segment:3
# E:\Data Science\genres\blues\blues.00046.wav, segment:4
# E:\Data Science\genres\blues\blues.00046.wav, segment:5
# E:\Data Science\genres\blues\blues.00046.wav, segment:6
# E:\Data Science\genres\blues\blues.00046.wav, segment:7
# E:\Data Science\genres\blues\blues.00046.wav, segment:8
# E:\Data Science\genres\blues\blues.00046.wav, segment:9
# E:\Data Science\genres\blues\blues.00046.wav, segment:10
# E:\Data Science\genres\blues\blues.00047.wav, segment:1
# E:\Data Science\genres\blues\blues.00047.wav, segment:2
# E:\Data Science\genres\blues\blues.00047.wav, segment:3
# E:\Data Science\genres\blues\blues.00047.wav, segment:4
# E:\Data Science\genres\blues\blues.00047.wav, segment:5
# E:\Data Science\genres\blues\blues.00047.wav, segment:6
# E:\Data Science\genres\blues\blues.00047.wav, segment:7
# E:\Data Science\genres\blues\blues.00047.wav, segment:8
# E:\Data Science\genres\blues\blues.00047.wav, segment:9
# E:\Data Science\genres\blues\blues.00047.wav, segment:10
# E:\Data Science\genres\blues\blues.00048.wav, segment:1
# E:\Data Science\genres\blues\blues.00048.wav, segment:2
# E:\Data Science\genres\blues\blues.00048.wav, segment:3
# E:\Data Science\genres\blues\blues.00048.wav, segment:4
# E:\Data Science\genres\blues\blues.00048.wav, segment:5
# E:\Data Science\genres\blues\blues.00048.wav, segment:6
# E:\Data Science\genres\blues\blues.00048.wav, segment:7
# E:\Data Science\genres\blues\blues.00048.wav, segment:8
# E:\Data Science\genres\blues\blues.00048.wav, segment:9
# E:\Data Science\genres\blues\blues.00048.wav, segment:10
# E:\Data Science\genres\blues\blues.00049.wav, segment:1
# E:\Data Science\genres\blues\blues.00049.wav, segment:2
# E:\Data Science\genres\blues\blues.00049.wav, segment:3
# E:\Data Science\genres\blues\blues.00049.wav, segment:4
# E:\Data Science\genres\blues\blues.00049.wav, segment:5
# E:\Data Science\genres\blues\blues.00049.wav, segment:6
# E:\Data Science\genres\blues\blues.00049.wav, segment:7
# E:\Data Science\genres\blues\blues.00049.wav, segment:8
# E:\Data Science\genres\blues\blues.00049.wav, segment:9
# E:\Data Science\genres\blues\blues.00049.wav, segment:10
# E:\Data Science\genres\blues\blues.00050.wav, segment:1
# E:\Data Science\genres\blues\blues.00050.wav, segment:2
# E:\Data Science\genres\blues\blues.00050.wav, segment:3
# E:\Data Science\genres\blues\blues.00050.wav, segment:4
# E:\Data Science\genres\blues\blues.00050.wav, segment:5
# E:\Data Science\genres\blues\blues.00050.wav, segment:6
# E:\Data Science\genres\blues\blues.00050.wav, segment:7
# E:\Data Science\genres\blues\blues.00050.wav, segment:8
# E:\Data Science\genres\blues\blues.00050.wav, segment:9
# E:\Data Science\genres\blues\blues.00050.wav, segment:10
# E:\Data Science\genres\blues\blues.00051.wav, segment:1
# E:\Data Science\genres\blues\blues.00051.wav, segment:2
# E:\Data Science\genres\blues\blues.00051.wav, segment:3
# E:\Data Science\genres\blues\blues.00051.wav, segment:4
# E:\Data Science\genres\blues\blues.00051.wav, segment:5
# E:\Data Science\genres\blues\blues.00051.wav, segment:6
# E:\Data Science\genres\blues\blues.00051.wav, segment:7
# E:\Data Science\genres\blues\blues.00051.wav, segment:8
# E:\Data Science\genres\blues\blues.00051.wav, segment:9
# E:\Data Science\genres\blues\blues.00051.wav, segment:10
# E:\Data Science\genres\blues\blues.00052.wav, segment:1
# E:\Data Science\genres\blues\blues.00052.wav, segment:2
# E:\Data Science\genres\blues\blues.00052.wav, segment:3
# E:\Data Science\genres\blues\blues.00052.wav, segment:4
# E:\Data Science\genres\blues\blues.00052.wav, segment:5
# E:\Data Science\genres\blues\blues.00052.wav, segment:6
# E:\Data Science\genres\blues\blues.00052.wav, segment:7
# E:\Data Science\genres\blues\blues.00052.wav, segment:8
# E:\Data Science\genres\blues\blues.00052.wav, segment:9
# E:\Data Science\genres\blues\blues.00052.wav, segment:10
# E:\Data Science\genres\blues\blues.00053.wav, segment:1
# E:\Data Science\genres\blues\blues.00053.wav, segment:2
# E:\Data Science\genres\blues\blues.00053.wav, segment:3
# E:\Data Science\genres\blues\blues.00053.wav, segment:4
# E:\Data Science\genres\blues\blues.00053.wav, segment:5
# E:\Data Science\genres\blues\blues.00053.wav, segment:6
# E:\Data Science\genres\blues\blues.00053.wav, segment:7
# E:\Data Science\genres\blues\blues.00053.wav, segment:8
# E:\Data Science\genres\blues\blues.00053.wav, segment:9
# E:\Data Science\genres\blues\blues.00053.wav, segment:10
# E:\Data Science\genres\blues\blues.00054.wav, segment:1
# E:\Data Science\genres\blues\blues.00054.wav, segment:2
# E:\Data Science\genres\blues\blues.00054.wav, segment:3
# E:\Data Science\genres\blues\blues.00054.wav, segment:4
# E:\Data Science\genres\blues\blues.00054.wav, segment:5
# E:\Data Science\genres\blues\blues.00054.wav, segment:6
# E:\Data Science\genres\blues\blues.00054.wav, segment:7
# E:\Data Science\genres\blues\blues.00054.wav, segment:8
# E:\Data Science\genres\blues\blues.00054.wav, segment:9
# E:\Data Science\genres\blues\blues.00054.wav, segment:10
# E:\Data Science\genres\blues\blues.00055.wav, segment:1
# E:\Data Science\genres\blues\blues.00055.wav, segment:2
# E:\Data Science\genres\blues\blues.00055.wav, segment:3
# E:\Data Science\genres\blues\blues.00055.wav, segment:4
# E:\Data Science\genres\blues\blues.00055.wav, segment:5
# E:\Data Science\genres\blues\blues.00055.wav, segment:6
# E:\Data Science\genres\blues\blues.00055.wav, segment:7
# E:\Data Science\genres\blues\blues.00055.wav, segment:8
# E:\Data Science\genres\blues\blues.00055.wav, segment:9
# E:\Data Science\genres\blues\blues.00055.wav, segment:10
# E:\Data Science\genres\blues\blues.00056.wav, segment:1
# E:\Data Science\genres\blues\blues.00056.wav, segment:2
# E:\Data Science\genres\blues\blues.00056.wav, segment:3
# E:\Data Science\genres\blues\blues.00056.wav, segment:4
# E:\Data Science\genres\blues\blues.00056.wav, segment:5
# E:\Data Science\genres\blues\blues.00056.wav, segment:6
# E:\Data Science\genres\blues\blues.00056.wav, segment:7
# E:\Data Science\genres\blues\blues.00056.wav, segment:8
# E:\Data Science\genres\blues\blues.00056.wav, segment:9
# E:\Data Science\genres\blues\blues.00056.wav, segment:10
# E:\Data Science\genres\blues\blues.00057.wav, segment:1
# E:\Data Science\genres\blues\blues.00057.wav, segment:2
# E:\Data Science\genres\blues\blues.00057.wav, segment:3
# E:\Data Science\genres\blues\blues.00057.wav, segment:4
# E:\Data Science\genres\blues\blues.00057.wav, segment:5
# E:\Data Science\genres\blues\blues.00057.wav, segment:6
# E:\Data Science\genres\blues\blues.00057.wav, segment:7
# E:\Data Science\genres\blues\blues.00057.wav, segment:8
# E:\Data Science\genres\blues\blues.00057.wav, segment:9
# E:\Data Science\genres\blues\blues.00057.wav, segment:10
# E:\Data Science\genres\blues\blues.00058.wav, segment:1
# E:\Data Science\genres\blues\blues.00058.wav, segment:2
# E:\Data Science\genres\blues\blues.00058.wav, segment:3
# E:\Data Science\genres\blues\blues.00058.wav, segment:4
# E:\Data Science\genres\blues\blues.00058.wav, segment:5
# E:\Data Science\genres\blues\blues.00058.wav, segment:6
# E:\Data Science\genres\blues\blues.00058.wav, segment:7
# E:\Data Science\genres\blues\blues.00058.wav, segment:8
# E:\Data Science\genres\blues\blues.00058.wav, segment:9
# E:\Data Science\genres\blues\blues.00058.wav, segment:10
# E:\Data Science\genres\blues\blues.00059.wav, segment:1
# E:\Data Science\genres\blues\blues.00059.wav, segment:2
# E:\Data Science\genres\blues\blues.00059.wav, segment:3
# E:\Data Science\genres\blues\blues.00059.wav, segment:4
# E:\Data Science\genres\blues\blues.00059.wav, segment:5
# E:\Data Science\genres\blues\blues.00059.wav, segment:6
# E:\Data Science\genres\blues\blues.00059.wav, segment:7
# E:\Data Science\genres\blues\blues.00059.wav, segment:8
# E:\Data Science\genres\blues\blues.00059.wav, segment:9
# E:\Data Science\genres\blues\blues.00059.wav, segment:10
# E:\Data Science\genres\blues\blues.00060.wav, segment:1
# E:\Data Science\genres\blues\blues.00060.wav, segment:2
# E:\Data Science\genres\blues\blues.00060.wav, segment:3
# E:\Data Science\genres\blues\blues.00060.wav, segment:4
# E:\Data Science\genres\blues\blues.00060.wav, segment:5
# E:\Data Science\genres\blues\blues.00060.wav, segment:6
# E:\Data Science\genres\blues\blues.00060.wav, segment:7
# E:\Data Science\genres\blues\blues.00060.wav, segment:8
# E:\Data Science\genres\blues\blues.00060.wav, segment:9
# E:\Data Science\genres\blues\blues.00060.wav, segment:10
# E:\Data Science\genres\blues\blues.00061.wav, segment:1
# E:\Data Science\genres\blues\blues.00061.wav, segment:2
# E:\Data Science\genres\blues\blues.00061.wav, segment:3
# E:\Data Science\genres\blues\blues.00061.wav, segment:4
# E:\Data Science\genres\blues\blues.00061.wav, segment:5
# E:\Data Science\genres\blues\blues.00061.wav, segment:6
# E:\Data Science\genres\blues\blues.00061.wav, segment:7
# E:\Data Science\genres\blues\blues.00061.wav, segment:8
# E:\Data Science\genres\blues\blues.00061.wav, segment:9
# E:\Data Science\genres\blues\blues.00061.wav, segment:10
# E:\Data Science\genres\blues\blues.00062.wav, segment:1
# E:\Data Science\genres\blues\blues.00062.wav, segment:2
# E:\Data Science\genres\blues\blues.00062.wav, segment:3
# E:\Data Science\genres\blues\blues.00062.wav, segment:4
# E:\Data Science\genres\blues\blues.00062.wav, segment:5
# E:\Data Science\genres\blues\blues.00062.wav, segment:6
# E:\Data Science\genres\blues\blues.00062.wav, segment:7
# E:\Data Science\genres\blues\blues.00062.wav, segment:8
# E:\Data Science\genres\blues\blues.00062.wav, segment:9
# E:\Data Science\genres\blues\blues.00062.wav, segment:10
# E:\Data Science\genres\blues\blues.00063.wav, segment:1
# E:\Data Science\genres\blues\blues.00063.wav, segment:2
# E:\Data Science\genres\blues\blues.00063.wav, segment:3
# E:\Data Science\genres\blues\blues.00063.wav, segment:4
# E:\Data Science\genres\blues\blues.00063.wav, segment:5
# E:\Data Science\genres\blues\blues.00063.wav, segment:6
# E:\Data Science\genres\blues\blues.00063.wav, segment:7
# E:\Data Science\genres\blues\blues.00063.wav, segment:8
# E:\Data Science\genres\blues\blues.00063.wav, segment:9
# E:\Data Science\genres\blues\blues.00063.wav, segment:10
# E:\Data Science\genres\blues\blues.00064.wav, segment:1
# E:\Data Science\genres\blues\blues.00064.wav, segment:2
# E:\Data Science\genres\blues\blues.00064.wav, segment:3
# E:\Data Science\genres\blues\blues.00064.wav, segment:4
# E:\Data Science\genres\blues\blues.00064.wav, segment:5
# E:\Data Science\genres\blues\blues.00064.wav, segment:6
# E:\Data Science\genres\blues\blues.00064.wav, segment:7
# E:\Data Science\genres\blues\blues.00064.wav, segment:8
# E:\Data Science\genres\blues\blues.00064.wav, segment:9
# E:\Data Science\genres\blues\blues.00064.wav, segment:10
# E:\Data Science\genres\blues\blues.00065.wav, segment:1
# E:\Data Science\genres\blues\blues.00065.wav, segment:2
# E:\Data Science\genres\blues\blues.00065.wav, segment:3
# E:\Data Science\genres\blues\blues.00065.wav, segment:4
# E:\Data Science\genres\blues\blues.00065.wav, segment:5
# E:\Data Science\genres\blues\blues.00065.wav, segment:6
# E:\Data Science\genres\blues\blues.00065.wav, segment:7
# E:\Data Science\genres\blues\blues.00065.wav, segment:8
# E:\Data Science\genres\blues\blues.00065.wav, segment:9
# E:\Data Science\genres\blues\blues.00065.wav, segment:10
# E:\Data Science\genres\blues\blues.00066.wav, segment:1
# E:\Data Science\genres\blues\blues.00066.wav, segment:2
# E:\Data Science\genres\blues\blues.00066.wav, segment:3
# E:\Data Science\genres\blues\blues.00066.wav, segment:4
# E:\Data Science\genres\blues\blues.00066.wav, segment:5
# E:\Data Science\genres\blues\blues.00066.wav, segment:6
# E:\Data Science\genres\blues\blues.00066.wav, segment:7
# E:\Data Science\genres\blues\blues.00066.wav, segment:8
# E:\Data Science\genres\blues\blues.00066.wav, segment:9
# E:\Data Science\genres\blues\blues.00066.wav, segment:10
# E:\Data Science\genres\blues\blues.00067.wav, segment:1
# E:\Data Science\genres\blues\blues.00067.wav, segment:2
# E:\Data Science\genres\blues\blues.00067.wav, segment:3
# E:\Data Science\genres\blues\blues.00067.wav, segment:4
# E:\Data Science\genres\blues\blues.00067.wav, segment:5
# E:\Data Science\genres\blues\blues.00067.wav, segment:6
# E:\Data Science\genres\blues\blues.00067.wav, segment:7
# E:\Data Science\genres\blues\blues.00067.wav, segment:8
# E:\Data Science\genres\blues\blues.00067.wav, segment:9
# E:\Data Science\genres\blues\blues.00067.wav, segment:10
# E:\Data Science\genres\blues\blues.00068.wav, segment:1
# E:\Data Science\genres\blues\blues.00068.wav, segment:2
# E:\Data Science\genres\blues\blues.00068.wav, segment:3
# E:\Data Science\genres\blues\blues.00068.wav, segment:4
# E:\Data Science\genres\blues\blues.00068.wav, segment:5
# E:\Data Science\genres\blues\blues.00068.wav, segment:6
# E:\Data Science\genres\blues\blues.00068.wav, segment:7
# E:\Data Science\genres\blues\blues.00068.wav, segment:8
# E:\Data Science\genres\blues\blues.00068.wav, segment:9
# E:\Data Science\genres\blues\blues.00068.wav, segment:10
# E:\Data Science\genres\blues\blues.00069.wav, segment:1
# E:\Data Science\genres\blues\blues.00069.wav, segment:2
# E:\Data Science\genres\blues\blues.00069.wav, segment:3
# E:\Data Science\genres\blues\blues.00069.wav, segment:4
# E:\Data Science\genres\blues\blues.00069.wav, segment:5
# E:\Data Science\genres\blues\blues.00069.wav, segment:6
# E:\Data Science\genres\blues\blues.00069.wav, segment:7
# E:\Data Science\genres\blues\blues.00069.wav, segment:8
# E:\Data Science\genres\blues\blues.00069.wav, segment:9
# E:\Data Science\genres\blues\blues.00069.wav, segment:10
# E:\Data Science\genres\blues\blues.00070.wav, segment:1
# E:\Data Science\genres\blues\blues.00070.wav, segment:2
# E:\Data Science\genres\blues\blues.00070.wav, segment:3
# E:\Data Science\genres\blues\blues.00070.wav, segment:4
# E:\Data Science\genres\blues\blues.00070.wav, segment:5
# E:\Data Science\genres\blues\blues.00070.wav, segment:6
# E:\Data Science\genres\blues\blues.00070.wav, segment:7
# E:\Data Science\genres\blues\blues.00070.wav, segment:8
# E:\Data Science\genres\blues\blues.00070.wav, segment:9
# E:\Data Science\genres\blues\blues.00070.wav, segment:10
# E:\Data Science\genres\blues\blues.00071.wav, segment:1
# E:\Data Science\genres\blues\blues.00071.wav, segment:2
# E:\Data Science\genres\blues\blues.00071.wav, segment:3
# E:\Data Science\genres\blues\blues.00071.wav, segment:4
# E:\Data Science\genres\blues\blues.00071.wav, segment:5
# E:\Data Science\genres\blues\blues.00071.wav, segment:6
# E:\Data Science\genres\blues\blues.00071.wav, segment:7
# E:\Data Science\genres\blues\blues.00071.wav, segment:8
# E:\Data Science\genres\blues\blues.00071.wav, segment:9
# E:\Data Science\genres\blues\blues.00071.wav, segment:10
# E:\Data Science\genres\blues\blues.00072.wav, segment:1
# E:\Data Science\genres\blues\blues.00072.wav, segment:2
# E:\Data Science\genres\blues\blues.00072.wav, segment:3
# E:\Data Science\genres\blues\blues.00072.wav, segment:4
# E:\Data Science\genres\blues\blues.00072.wav, segment:5
# E:\Data Science\genres\blues\blues.00072.wav, segment:6
# E:\Data Science\genres\blues\blues.00072.wav, segment:7
# E:\Data Science\genres\blues\blues.00072.wav, segment:8
# E:\Data Science\genres\blues\blues.00072.wav, segment:9
# E:\Data Science\genres\blues\blues.00072.wav, segment:10
# E:\Data Science\genres\blues\blues.00073.wav, segment:1
# E:\Data Science\genres\blues\blues.00073.wav, segment:2
# E:\Data Science\genres\blues\blues.00073.wav, segment:3
# E:\Data Science\genres\blues\blues.00073.wav, segment:4
# E:\Data Science\genres\blues\blues.00073.wav, segment:5
# E:\Data Science\genres\blues\blues.00073.wav, segment:6
# E:\Data Science\genres\blues\blues.00073.wav, segment:7
# E:\Data Science\genres\blues\blues.00073.wav, segment:8
# E:\Data Science\genres\blues\blues.00073.wav, segment:9
# E:\Data Science\genres\blues\blues.00073.wav, segment:10
# E:\Data Science\genres\blues\blues.00074.wav, segment:1
# E:\Data Science\genres\blues\blues.00074.wav, segment:2
# E:\Data Science\genres\blues\blues.00074.wav, segment:3
# E:\Data Science\genres\blues\blues.00074.wav, segment:4
# E:\Data Science\genres\blues\blues.00074.wav, segment:5
# E:\Data Science\genres\blues\blues.00074.wav, segment:6
# E:\Data Science\genres\blues\blues.00074.wav, segment:7
# E:\Data Science\genres\blues\blues.00074.wav, segment:8
# E:\Data Science\genres\blues\blues.00074.wav, segment:9
# E:\Data Science\genres\blues\blues.00074.wav, segment:10
# E:\Data Science\genres\blues\blues.00075.wav, segment:1
# E:\Data Science\genres\blues\blues.00075.wav, segment:2
# E:\Data Science\genres\blues\blues.00075.wav, segment:3
# E:\Data Science\genres\blues\blues.00075.wav, segment:4
# E:\Data Science\genres\blues\blues.00075.wav, segment:5
# E:\Data Science\genres\blues\blues.00075.wav, segment:6
# E:\Data Science\genres\blues\blues.00075.wav, segment:7
# E:\Data Science\genres\blues\blues.00075.wav, segment:8
# E:\Data Science\genres\blues\blues.00075.wav, segment:9
# E:\Data Science\genres\blues\blues.00075.wav, segment:10
# E:\Data Science\genres\blues\blues.00076.wav, segment:1
# E:\Data Science\genres\blues\blues.00076.wav, segment:2
# E:\Data Science\genres\blues\blues.00076.wav, segment:3
# E:\Data Science\genres\blues\blues.00076.wav, segment:4
# E:\Data Science\genres\blues\blues.00076.wav, segment:5
# E:\Data Science\genres\blues\blues.00076.wav, segment:6
# E:\Data Science\genres\blues\blues.00076.wav, segment:7
# E:\Data Science\genres\blues\blues.00076.wav, segment:8
# E:\Data Science\genres\blues\blues.00076.wav, segment:9
# E:\Data Science\genres\blues\blues.00076.wav, segment:10
# E:\Data Science\genres\blues\blues.00077.wav, segment:1
# E:\Data Science\genres\blues\blues.00077.wav, segment:2
# E:\Data Science\genres\blues\blues.00077.wav, segment:3
# E:\Data Science\genres\blues\blues.00077.wav, segment:4
# E:\Data Science\genres\blues\blues.00077.wav, segment:5
# E:\Data Science\genres\blues\blues.00077.wav, segment:6
# E:\Data Science\genres\blues\blues.00077.wav, segment:7
# E:\Data Science\genres\blues\blues.00077.wav, segment:8
# E:\Data Science\genres\blues\blues.00077.wav, segment:9
# E:\Data Science\genres\blues\blues.00077.wav, segment:10
# E:\Data Science\genres\blues\blues.00078.wav, segment:1
# E:\Data Science\genres\blues\blues.00078.wav, segment:2
# E:\Data Science\genres\blues\blues.00078.wav, segment:3
# E:\Data Science\genres\blues\blues.00078.wav, segment:4
# E:\Data Science\genres\blues\blues.00078.wav, segment:5
# E:\Data Science\genres\blues\blues.00078.wav, segment:6
# E:\Data Science\genres\blues\blues.00078.wav, segment:7
# E:\Data Science\genres\blues\blues.00078.wav, segment:8
# E:\Data Science\genres\blues\blues.00078.wav, segment:9
# E:\Data Science\genres\blues\blues.00078.wav, segment:10
# E:\Data Science\genres\blues\blues.00079.wav, segment:1
# E:\Data Science\genres\blues\blues.00079.wav, segment:2
# E:\Data Science\genres\blues\blues.00079.wav, segment:3
# E:\Data Science\genres\blues\blues.00079.wav, segment:4
# E:\Data Science\genres\blues\blues.00079.wav, segment:5
# E:\Data Science\genres\blues\blues.00079.wav, segment:6
# E:\Data Science\genres\blues\blues.00079.wav, segment:7
# E:\Data Science\genres\blues\blues.00079.wav, segment:8
# E:\Data Science\genres\blues\blues.00079.wav, segment:9
# E:\Data Science\genres\blues\blues.00079.wav, segment:10
# E:\Data Science\genres\blues\blues.00080.wav, segment:1
# E:\Data Science\genres\blues\blues.00080.wav, segment:2
# E:\Data Science\genres\blues\blues.00080.wav, segment:3
# E:\Data Science\genres\blues\blues.00080.wav, segment:4
# E:\Data Science\genres\blues\blues.00080.wav, segment:5
# E:\Data Science\genres\blues\blues.00080.wav, segment:6
# E:\Data Science\genres\blues\blues.00080.wav, segment:7
# E:\Data Science\genres\blues\blues.00080.wav, segment:8
# E:\Data Science\genres\blues\blues.00080.wav, segment:9
# E:\Data Science\genres\blues\blues.00080.wav, segment:10
# E:\Data Science\genres\blues\blues.00081.wav, segment:1
# E:\Data Science\genres\blues\blues.00081.wav, segment:2
# E:\Data Science\genres\blues\blues.00081.wav, segment:3
# E:\Data Science\genres\blues\blues.00081.wav, segment:4
# E:\Data Science\genres\blues\blues.00081.wav, segment:5
# E:\Data Science\genres\blues\blues.00081.wav, segment:6
# E:\Data Science\genres\blues\blues.00081.wav, segment:7
# E:\Data Science\genres\blues\blues.00081.wav, segment:8
# E:\Data Science\genres\blues\blues.00081.wav, segment:9
# E:\Data Science\genres\blues\blues.00081.wav, segment:10
# E:\Data Science\genres\blues\blues.00082.wav, segment:1
# E:\Data Science\genres\blues\blues.00082.wav, segment:2
# E:\Data Science\genres\blues\blues.00082.wav, segment:3
# E:\Data Science\genres\blues\blues.00082.wav, segment:4
# E:\Data Science\genres\blues\blues.00082.wav, segment:5
# E:\Data Science\genres\blues\blues.00082.wav, segment:6
# E:\Data Science\genres\blues\blues.00082.wav, segment:7
# E:\Data Science\genres\blues\blues.00082.wav, segment:8
# E:\Data Science\genres\blues\blues.00082.wav, segment:9
# E:\Data Science\genres\blues\blues.00082.wav, segment:10
# E:\Data Science\genres\blues\blues.00083.wav, segment:1
# E:\Data Science\genres\blues\blues.00083.wav, segment:2
# E:\Data Science\genres\blues\blues.00083.wav, segment:3
# E:\Data Science\genres\blues\blues.00083.wav, segment:4
# E:\Data Science\genres\blues\blues.00083.wav, segment:5
# E:\Data Science\genres\blues\blues.00083.wav, segment:6
# E:\Data Science\genres\blues\blues.00083.wav, segment:7
# E:\Data Science\genres\blues\blues.00083.wav, segment:8
# E:\Data Science\genres\blues\blues.00083.wav, segment:9
# E:\Data Science\genres\blues\blues.00083.wav, segment:10
# E:\Data Science\genres\blues\blues.00084.wav, segment:1
# E:\Data Science\genres\blues\blues.00084.wav, segment:2
# E:\Data Science\genres\blues\blues.00084.wav, segment:3
# E:\Data Science\genres\blues\blues.00084.wav, segment:4
# E:\Data Science\genres\blues\blues.00084.wav, segment:5
# E:\Data Science\genres\blues\blues.00084.wav, segment:6
# E:\Data Science\genres\blues\blues.00084.wav, segment:7
# E:\Data Science\genres\blues\blues.00084.wav, segment:8
# E:\Data Science\genres\blues\blues.00084.wav, segment:9
# E:\Data Science\genres\blues\blues.00084.wav, segment:10
# E:\Data Science\genres\blues\blues.00085.wav, segment:1
# E:\Data Science\genres\blues\blues.00085.wav, segment:2
# E:\Data Science\genres\blues\blues.00085.wav, segment:3
# E:\Data Science\genres\blues\blues.00085.wav, segment:4
# ...
# E:\Data Science\genres\rock\rock.00070.wav, segment:6
# E:\Data Science\genres\rock\rock.00070.wav, segment:7
# E:\Data Science\genres\rock\rock.00070.wav, segment:8
# E:\Data Science\genres\rock\rock.00070.wav, segment:9
# E:\Data Science\genres\rock\rock.00070.wav, segment:10
# E:\Data Science\genres\rock\rock.00071.wav, segment:1
# E:\Data Science\genres\rock\rock.00071.wav, segment:2
# E:\Data Science\genres\rock\rock.00071.wav, segment:3
# E:\Data Science\genres\rock\rock.00071.wav, segment:4
# E:\Data Science\genres\rock\rock.00071.wav, segment:5
# E:\Data Science\genres\rock\rock.00071.wav, segment:6
# E:\Data Science\genres\rock\rock.00071.wav, segment:7
# E:\Data Science\genres\rock\rock.00071.wav, segment:8
# E:\Data Science\genres\rock\rock.00071.wav, segment:9
# E:\Data Science\genres\rock\rock.00071.wav, segment:10
# E:\Data Science\genres\rock\rock.00072.wav, segment:1
# E:\Data Science\genres\rock\rock.00072.wav, segment:2
# E:\Data Science\genres\rock\rock.00072.wav, segment:3
# E:\Data Science\genres\rock\rock.00072.wav, segment:4
# E:\Data Science\genres\rock\rock.00072.wav, segment:5
# E:\Data Science\genres\rock\rock.00072.wav, segment:6
# E:\Data Science\genres\rock\rock.00072.wav, segment:7
# E:\Data Science\genres\rock\rock.00072.wav, segment:8
# E:\Data Science\genres\rock\rock.00072.wav, segment:9
# E:\Data Science\genres\rock\rock.00072.wav, segment:10
# E:\Data Science\genres\rock\rock.00073.wav, segment:1
# E:\Data Science\genres\rock\rock.00073.wav, segment:2
# E:\Data Science\genres\rock\rock.00073.wav, segment:3
# E:\Data Science\genres\rock\rock.00073.wav, segment:4
# E:\Data Science\genres\rock\rock.00073.wav, segment:5
# E:\Data Science\genres\rock\rock.00073.wav, segment:6
# E:\Data Science\genres\rock\rock.00073.wav, segment:7
# E:\Data Science\genres\rock\rock.00073.wav, segment:8
# E:\Data Science\genres\rock\rock.00073.wav, segment:9
# E:\Data Science\genres\rock\rock.00073.wav, segment:10
# E:\Data Science\genres\rock\rock.00074.wav, segment:1
# E:\Data Science\genres\rock\rock.00074.wav, segment:2
# E:\Data Science\genres\rock\rock.00074.wav, segment:3
# E:\Data Science\genres\rock\rock.00074.wav, segment:4
# E:\Data Science\genres\rock\rock.00074.wav, segment:5
# E:\Data Science\genres\rock\rock.00074.wav, segment:6
# E:\Data Science\genres\rock\rock.00074.wav, segment:7
# E:\Data Science\genres\rock\rock.00074.wav, segment:8
# E:\Data Science\genres\rock\rock.00074.wav, segment:9
# E:\Data Science\genres\rock\rock.00074.wav, segment:10
# E:\Data Science\genres\rock\rock.00075.wav, segment:1
# E:\Data Science\genres\rock\rock.00075.wav, segment:2
# E:\Data Science\genres\rock\rock.00075.wav, segment:3
# E:\Data Science\genres\rock\rock.00075.wav, segment:4
# E:\Data Science\genres\rock\rock.00075.wav, segment:5
# E:\Data Science\genres\rock\rock.00075.wav, segment:6
# E:\Data Science\genres\rock\rock.00075.wav, segment:7
# E:\Data Science\genres\rock\rock.00075.wav, segment:8
# E:\Data Science\genres\rock\rock.00075.wav, segment:9
# E:\Data Science\genres\rock\rock.00075.wav, segment:10
# E:\Data Science\genres\rock\rock.00076.wav, segment:1
# E:\Data Science\genres\rock\rock.00076.wav, segment:2
# E:\Data Science\genres\rock\rock.00076.wav, segment:3
# E:\Data Science\genres\rock\rock.00076.wav, segment:4
# E:\Data Science\genres\rock\rock.00076.wav, segment:5
# E:\Data Science\genres\rock\rock.00076.wav, segment:6
# E:\Data Science\genres\rock\rock.00076.wav, segment:7
# E:\Data Science\genres\rock\rock.00076.wav, segment:8
# E:\Data Science\genres\rock\rock.00076.wav, segment:9
# E:\Data Science\genres\rock\rock.00076.wav, segment:10
# E:\Data Science\genres\rock\rock.00077.wav, segment:1
# E:\Data Science\genres\rock\rock.00077.wav, segment:2
# E:\Data Science\genres\rock\rock.00077.wav, segment:3
# E:\Data Science\genres\rock\rock.00077.wav, segment:4
# E:\Data Science\genres\rock\rock.00077.wav, segment:5
# E:\Data Science\genres\rock\rock.00077.wav, segment:6
# E:\Data Science\genres\rock\rock.00077.wav, segment:7
# E:\Data Science\genres\rock\rock.00077.wav, segment:8
# E:\Data Science\genres\rock\rock.00077.wav, segment:9
# E:\Data Science\genres\rock\rock.00077.wav, segment:10
# E:\Data Science\genres\rock\rock.00078.wav, segment:1
# E:\Data Science\genres\rock\rock.00078.wav, segment:2
# E:\Data Science\genres\rock\rock.00078.wav, segment:3
# E:\Data Science\genres\rock\rock.00078.wav, segment:4
# E:\Data Science\genres\rock\rock.00078.wav, segment:5
# E:\Data Science\genres\rock\rock.00078.wav, segment:6
# E:\Data Science\genres\rock\rock.00078.wav, segment:7
# E:\Data Science\genres\rock\rock.00078.wav, segment:8
# E:\Data Science\genres\rock\rock.00078.wav, segment:9
# E:\Data Science\genres\rock\rock.00078.wav, segment:10
# E:\Data Science\genres\rock\rock.00079.wav, segment:1
# E:\Data Science\genres\rock\rock.00079.wav, segment:2
# E:\Data Science\genres\rock\rock.00079.wav, segment:3
# E:\Data Science\genres\rock\rock.00079.wav, segment:4
# E:\Data Science\genres\rock\rock.00079.wav, segment:5
# E:\Data Science\genres\rock\rock.00079.wav, segment:6
# E:\Data Science\genres\rock\rock.00079.wav, segment:7
# E:\Data Science\genres\rock\rock.00079.wav, segment:8
# E:\Data Science\genres\rock\rock.00079.wav, segment:9
# E:\Data Science\genres\rock\rock.00079.wav, segment:10
# E:\Data Science\genres\rock\rock.00080.wav, segment:1
# E:\Data Science\genres\rock\rock.00080.wav, segment:2
# E:\Data Science\genres\rock\rock.00080.wav, segment:3
# E:\Data Science\genres\rock\rock.00080.wav, segment:4
# E:\Data Science\genres\rock\rock.00080.wav, segment:5
# E:\Data Science\genres\rock\rock.00080.wav, segment:6
# E:\Data Science\genres\rock\rock.00080.wav, segment:7
# E:\Data Science\genres\rock\rock.00080.wav, segment:8
# E:\Data Science\genres\rock\rock.00080.wav, segment:9
# E:\Data Science\genres\rock\rock.00080.wav, segment:10
# E:\Data Science\genres\rock\rock.00081.wav, segment:1
# E:\Data Science\genres\rock\rock.00081.wav, segment:2
# E:\Data Science\genres\rock\rock.00081.wav, segment:3
# E:\Data Science\genres\rock\rock.00081.wav, segment:4
# E:\Data Science\genres\rock\rock.00081.wav, segment:5
# E:\Data Science\genres\rock\rock.00081.wav, segment:6
# E:\Data Science\genres\rock\rock.00081.wav, segment:7
# E:\Data Science\genres\rock\rock.00081.wav, segment:8
# E:\Data Science\genres\rock\rock.00081.wav, segment:9
# E:\Data Science\genres\rock\rock.00081.wav, segment:10
# E:\Data Science\genres\rock\rock.00082.wav, segment:1
# E:\Data Science\genres\rock\rock.00082.wav, segment:2
# E:\Data Science\genres\rock\rock.00082.wav, segment:3
# E:\Data Science\genres\rock\rock.00082.wav, segment:4
# E:\Data Science\genres\rock\rock.00082.wav, segment:5
# E:\Data Science\genres\rock\rock.00082.wav, segment:6
# E:\Data Science\genres\rock\rock.00082.wav, segment:7
# E:\Data Science\genres\rock\rock.00082.wav, segment:8
# E:\Data Science\genres\rock\rock.00082.wav, segment:9
# E:\Data Science\genres\rock\rock.00082.wav, segment:10
# E:\Data Science\genres\rock\rock.00083.wav, segment:1
# E:\Data Science\genres\rock\rock.00083.wav, segment:2
# E:\Data Science\genres\rock\rock.00083.wav, segment:3
# E:\Data Science\genres\rock\rock.00083.wav, segment:4
# E:\Data Science\genres\rock\rock.00083.wav, segment:5
# E:\Data Science\genres\rock\rock.00083.wav, segment:6
# E:\Data Science\genres\rock\rock.00083.wav, segment:7
# E:\Data Science\genres\rock\rock.00083.wav, segment:8
# E:\Data Science\genres\rock\rock.00083.wav, segment:9
# E:\Data Science\genres\rock\rock.00083.wav, segment:10
# E:\Data Science\genres\rock\rock.00084.wav, segment:1
# E:\Data Science\genres\rock\rock.00084.wav, segment:2
# E:\Data Science\genres\rock\rock.00084.wav, segment:3
# E:\Data Science\genres\rock\rock.00084.wav, segment:4
# E:\Data Science\genres\rock\rock.00084.wav, segment:5
# E:\Data Science\genres\rock\rock.00084.wav, segment:6
# E:\Data Science\genres\rock\rock.00084.wav, segment:7
# E:\Data Science\genres\rock\rock.00084.wav, segment:8
# E:\Data Science\genres\rock\rock.00084.wav, segment:9
# E:\Data Science\genres\rock\rock.00084.wav, segment:10
# E:\Data Science\genres\rock\rock.00085.wav, segment:1
# E:\Data Science\genres\rock\rock.00085.wav, segment:2
# E:\Data Science\genres\rock\rock.00085.wav, segment:3
# E:\Data Science\genres\rock\rock.00085.wav, segment:4
# E:\Data Science\genres\rock\rock.00085.wav, segment:5
# E:\Data Science\genres\rock\rock.00085.wav, segment:6
# E:\Data Science\genres\rock\rock.00085.wav, segment:7
# E:\Data Science\genres\rock\rock.00085.wav, segment:8
# E:\Data Science\genres\rock\rock.00085.wav, segment:9
# E:\Data Science\genres\rock\rock.00085.wav, segment:10
# E:\Data Science\genres\rock\rock.00086.wav, segment:1
# E:\Data Science\genres\rock\rock.00086.wav, segment:2
# E:\Data Science\genres\rock\rock.00086.wav, segment:3
# E:\Data Science\genres\rock\rock.00086.wav, segment:4
# E:\Data Science\genres\rock\rock.00086.wav, segment:5
# E:\Data Science\genres\rock\rock.00086.wav, segment:6
# E:\Data Science\genres\rock\rock.00086.wav, segment:7
# E:\Data Science\genres\rock\rock.00086.wav, segment:8
# E:\Data Science\genres\rock\rock.00086.wav, segment:9
# E:\Data Science\genres\rock\rock.00086.wav, segment:10
# E:\Data Science\genres\rock\rock.00087.wav, segment:1
# E:\Data Science\genres\rock\rock.00087.wav, segment:2
# E:\Data Science\genres\rock\rock.00087.wav, segment:3
# E:\Data Science\genres\rock\rock.00087.wav, segment:4
# E:\Data Science\genres\rock\rock.00087.wav, segment:5
# E:\Data Science\genres\rock\rock.00087.wav, segment:6
# E:\Data Science\genres\rock\rock.00087.wav, segment:7
# E:\Data Science\genres\rock\rock.00087.wav, segment:8
# E:\Data Science\genres\rock\rock.00087.wav, segment:9
# E:\Data Science\genres\rock\rock.00087.wav, segment:10
# E:\Data Science\genres\rock\rock.00088.wav, segment:1
# E:\Data Science\genres\rock\rock.00088.wav, segment:2
# E:\Data Science\genres\rock\rock.00088.wav, segment:3
# E:\Data Science\genres\rock\rock.00088.wav, segment:4
# E:\Data Science\genres\rock\rock.00088.wav, segment:5
# E:\Data Science\genres\rock\rock.00088.wav, segment:6
# E:\Data Science\genres\rock\rock.00088.wav, segment:7
# E:\Data Science\genres\rock\rock.00088.wav, segment:8
# E:\Data Science\genres\rock\rock.00088.wav, segment:9
# E:\Data Science\genres\rock\rock.00088.wav, segment:10
# E:\Data Science\genres\rock\rock.00089.wav, segment:1
# E:\Data Science\genres\rock\rock.00089.wav, segment:2
# E:\Data Science\genres\rock\rock.00089.wav, segment:3
# E:\Data Science\genres\rock\rock.00089.wav, segment:4
# E:\Data Science\genres\rock\rock.00089.wav, segment:5
# E:\Data Science\genres\rock\rock.00089.wav, segment:6
# E:\Data Science\genres\rock\rock.00089.wav, segment:7
# E:\Data Science\genres\rock\rock.00089.wav, segment:8
# E:\Data Science\genres\rock\rock.00089.wav, segment:9
# E:\Data Science\genres\rock\rock.00089.wav, segment:10
# E:\Data Science\genres\rock\rock.00090.wav, segment:1
# E:\Data Science\genres\rock\rock.00090.wav, segment:2
# E:\Data Science\genres\rock\rock.00090.wav, segment:3
# E:\Data Science\genres\rock\rock.00090.wav, segment:4
# E:\Data Science\genres\rock\rock.00090.wav, segment:5
# E:\Data Science\genres\rock\rock.00090.wav, segment:6
# E:\Data Science\genres\rock\rock.00090.wav, segment:7
# E:\Data Science\genres\rock\rock.00090.wav, segment:8
# E:\Data Science\genres\rock\rock.00090.wav, segment:9
# E:\Data Science\genres\rock\rock.00090.wav, segment:10
# E:\Data Science\genres\rock\rock.00091.wav, segment:1
# E:\Data Science\genres\rock\rock.00091.wav, segment:2
# E:\Data Science\genres\rock\rock.00091.wav, segment:3
# E:\Data Science\genres\rock\rock.00091.wav, segment:4
# E:\Data Science\genres\rock\rock.00091.wav, segment:5
# E:\Data Science\genres\rock\rock.00091.wav, segment:6
# E:\Data Science\genres\rock\rock.00091.wav, segment:7
# E:\Data Science\genres\rock\rock.00091.wav, segment:8
# E:\Data Science\genres\rock\rock.00091.wav, segment:9
# E:\Data Science\genres\rock\rock.00091.wav, segment:10
# E:\Data Science\genres\rock\rock.00092.wav, segment:1
# E:\Data Science\genres\rock\rock.00092.wav, segment:2
# E:\Data Science\genres\rock\rock.00092.wav, segment:3
# E:\Data Science\genres\rock\rock.00092.wav, segment:4
# E:\Data Science\genres\rock\rock.00092.wav, segment:5
# E:\Data Science\genres\rock\rock.00092.wav, segment:6
# E:\Data Science\genres\rock\rock.00092.wav, segment:7
# E:\Data Science\genres\rock\rock.00092.wav, segment:8
# E:\Data Science\genres\rock\rock.00092.wav, segment:9
# E:\Data Science\genres\rock\rock.00092.wav, segment:10
# E:\Data Science\genres\rock\rock.00093.wav, segment:1
# E:\Data Science\genres\rock\rock.00093.wav, segment:2
# E:\Data Science\genres\rock\rock.00093.wav, segment:3
# E:\Data Science\genres\rock\rock.00093.wav, segment:4
# E:\Data Science\genres\rock\rock.00093.wav, segment:5
# E:\Data Science\genres\rock\rock.00093.wav, segment:6
# E:\Data Science\genres\rock\rock.00093.wav, segment:7
# E:\Data Science\genres\rock\rock.00093.wav, segment:8
# E:\Data Science\genres\rock\rock.00093.wav, segment:9
# E:\Data Science\genres\rock\rock.00093.wav, segment:10
# E:\Data Science\genres\rock\rock.00094.wav, segment:1
# E:\Data Science\genres\rock\rock.00094.wav, segment:2
# E:\Data Science\genres\rock\rock.00094.wav, segment:3
# E:\Data Science\genres\rock\rock.00094.wav, segment:4
# E:\Data Science\genres\rock\rock.00094.wav, segment:5
# E:\Data Science\genres\rock\rock.00094.wav, segment:6
# E:\Data Science\genres\rock\rock.00094.wav, segment:7
# E:\Data Science\genres\rock\rock.00094.wav, segment:8
# E:\Data Science\genres\rock\rock.00094.wav, segment:9
# E:\Data Science\genres\rock\rock.00094.wav, segment:10
# E:\Data Science\genres\rock\rock.00095.wav, segment:1
# E:\Data Science\genres\rock\rock.00095.wav, segment:2
# E:\Data Science\genres\rock\rock.00095.wav, segment:3
# E:\Data Science\genres\rock\rock.00095.wav, segment:4
# E:\Data Science\genres\rock\rock.00095.wav, segment:5
# E:\Data Science\genres\rock\rock.00095.wav, segment:6
# E:\Data Science\genres\rock\rock.00095.wav, segment:7
# E:\Data Science\genres\rock\rock.00095.wav, segment:8
# E:\Data Science\genres\rock\rock.00095.wav, segment:9
# E:\Data Science\genres\rock\rock.00095.wav, segment:10
# E:\Data Science\genres\rock\rock.00096.wav, segment:1
# E:\Data Science\genres\rock\rock.00096.wav, segment:2
# E:\Data Science\genres\rock\rock.00096.wav, segment:3
# E:\Data Science\genres\rock\rock.00096.wav, segment:4
# E:\Data Science\genres\rock\rock.00096.wav, segment:5
# E:\Data Science\genres\rock\rock.00096.wav, segment:6
# E:\Data Science\genres\rock\rock.00096.wav, segment:7
# E:\Data Science\genres\rock\rock.00096.wav, segment:8
# E:\Data Science\genres\rock\rock.00096.wav, segment:9
# E:\Data Science\genres\rock\rock.00096.wav, segment:10
# E:\Data Science\genres\rock\rock.00097.wav, segment:1
# E:\Data Science\genres\rock\rock.00097.wav, segment:2
# E:\Data Science\genres\rock\rock.00097.wav, segment:3
# E:\Data Science\genres\rock\rock.00097.wav, segment:4
# E:\Data Science\genres\rock\rock.00097.wav, segment:5
# E:\Data Science\genres\rock\rock.00097.wav, segment:6
# E:\Data Science\genres\rock\rock.00097.wav, segment:7
# E:\Data Science\genres\rock\rock.00097.wav, segment:8
# E:\Data Science\genres\rock\rock.00097.wav, segment:9
# E:\Data Science\genres\rock\rock.00097.wav, segment:10
# E:\Data Science\genres\rock\rock.00098.wav, segment:1
# E:\Data Science\genres\rock\rock.00098.wav, segment:2
# E:\Data Science\genres\rock\rock.00098.wav, segment:3
# E:\Data Science\genres\rock\rock.00098.wav, segment:4
# E:\Data Science\genres\rock\rock.00098.wav, segment:5
# E:\Data Science\genres\rock\rock.00098.wav, segment:6
# E:\Data Science\genres\rock\rock.00098.wav, segment:7
# E:\Data Science\genres\rock\rock.00098.wav, segment:8
# E:\Data Science\genres\rock\rock.00098.wav, segment:9
# E:\Data Science\genres\rock\rock.00098.wav, segment:10
# E:\Data Science\genres\rock\rock.00099.wav, segment:1
# E:\Data Science\genres\rock\rock.00099.wav, segment:2
# E:\Data Science\genres\rock\rock.00099.wav, segment:3
# E:\Data Science\genres\rock\rock.00099.wav, segment:4
# E:\Data Science\genres\rock\rock.00099.wav, segment:5
# E:\Data Science\genres\rock\rock.00099.wav, segment:6
# E:\Data Science\genres\rock\rock.00099.wav, segment:7
# E:\Data Science\genres\rock\rock.00099.wav, segment:8
# E:\Data Science\genres\rock\rock.00099.wav, segment:9
# E:\Data Science\genres\rock\rock.00099.wav, segment:10

# %%
#CNN Model For Classification

import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

DATA_PATH = "data_10.json"


def load_data(data_path):
    """Loads training dataset from json file.
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    return X, y

  
def prepare_datasets(test_size, validation_size):
    """Loads data and splits it into train, validation and test sets.
    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split
    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    """

    # load data
    X, y = load_data(DATA_PATH)

    # create train, validation and test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # add an axis to input sets
    X_train = X_train[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test


def build_model(input_shape):
    """Generates CNN model
    :param input_shape (tuple): Shape of input set
    :return model: CNN model
    """

    # build network topology
    model = keras.Sequential()

    # 1st conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 2nd conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu'))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 3rd conv layer
    model.add(keras.layers.Conv2D(32, (2, 2), activation='relu'))
    model.add(keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # flatten output and feed it into dense layer
    model.add(keras.layers.Flatten())
    
    # 1st dense layer
    keras.layers.Dense(512, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.5),

    # 2nd dense layer
    keras.layers.Dense(256, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.3),

    # 3rd dense layer
    keras.layers.Dense(64, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.2),


    # output layer
    model.add(keras.layers.Dense(10, activation='softmax'))

    return model


def predict(model, X, y):
    """Predict a single sample using the trained model
    :param model: Trained classifier
    :param X: Input data
    :param y (int): Target
    """

    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    # perform prediction
    prediction = model.predict(X)

    # get index with max value
    predicted_index = np.argmax(prediction, axis=1)

    print("Target: {}, Predicted label: {}".format(y, predicted_index))


if __name__ == "__main__":

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.15, 0.15)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    model = build_model(input_shape)

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=50, epochs=40)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)

    # pick a sample to predict from the test set
    X_to_predict = X_test[100]
    y_to_predict = y_test[100]

    # predict sample
    predict(model, X_to_predict, y_to_predict)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 128, 11, 32)       320
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 64, 6, 32)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64, 6, 32)         128
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 62, 4, 32)         9248
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 31, 2, 32)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 31, 2, 32)         128
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 30, 1, 32)         4128
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 15, 1, 32)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 15, 1, 32)         128
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 480)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                4810
# =================================================================
# Total params: 18,890
# Trainable params: 18,698
# Non-trainable params: 192
# _________________________________________________________________
# Train on 7221 samples, validate on 1275 samples
# Epoch 1/40
# 7221/7221 [==============================] - 17s 2ms/sample - loss: 1.5794 - acc: 0.4559 - val_loss: 2.2316 - val_acc: 0.3184
# Epoch 2/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 1.1035 - acc: 0.6133 - val_loss: 1.2163 - val_acc: 0.5780
# Epoch 3/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.9253 - acc: 0.6764 - val_loss: 1.0608 - val_acc: 0.6220
# Epoch 4/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.8294 - acc: 0.7088 - val_loss: 0.9241 - val_acc: 0.6722
# Epoch 5/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.7298 - acc: 0.7460 - val_loss: 0.8556 - val_acc: 0.7020
# Epoch 6/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.6631 - acc: 0.7703 - val_loss: 0.8806 - val_acc: 0.7067
# Epoch 7/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.6183 - acc: 0.7865 - val_loss: 0.8826 - val_acc: 0.7137
# Epoch 8/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.5627 - acc: 0.8078 - val_loss: 0.8835 - val_acc: 0.6871
# Epoch 9/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.5186 - acc: 0.8216 - val_loss: 0.9896 - val_acc: 0.6800
# Epoch 10/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.4826 - acc: 0.8342 - val_loss: 0.7746 - val_acc: 0.7427
# Epoch 11/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.4563 - acc: 0.8456 - val_loss: 0.9252 - val_acc: 0.7012
# Epoch 12/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.4191 - acc: 0.8582 - val_loss: 0.7586 - val_acc: 0.7498
# Epoch 13/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.3932 - acc: 0.8677 - val_loss: 0.8512 - val_acc: 0.7153
# Epoch 14/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.3718 - acc: 0.8726 - val_loss: 0.8189 - val_acc: 0.7404
# Epoch 15/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.3469 - acc: 0.8792 - val_loss: 0.8970 - val_acc: 0.7122
# Epoch 16/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.3210 - acc: 0.8896 - val_loss: 0.7744 - val_acc: 0.7522
# Epoch 17/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.3067 - acc: 0.8896 - val_loss: 0.7312 - val_acc: 0.7686
# Epoch 18/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.2773 - acc: 0.9044 - val_loss: 0.7758 - val_acc: 0.7427
# Epoch 19/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.2759 - acc: 0.9044 - val_loss: 0.9732 - val_acc: 0.7176
# Epoch 20/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.2506 - acc: 0.9154 - val_loss: 0.8437 - val_acc: 0.7475
# Epoch 21/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.2368 - acc: 0.9172 - val_loss: 0.9245 - val_acc: 0.7396
# Epoch 22/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.2228 - acc: 0.9234 - val_loss: 0.8664 - val_acc: 0.7506
# Epoch 23/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.2162 - acc: 0.9263 - val_loss: 0.9801 - val_acc: 0.7255
# Epoch 24/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.1924 - acc: 0.9337 - val_loss: 0.7754 - val_acc: 0.7655
# Epoch 25/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.1782 - acc: 0.9392 - val_loss: 0.7683 - val_acc: 0.7694
# Epoch 26/40
# 7221/7221 [==============================] - 16s 2ms/sample - loss: 0.1794 - acc: 0.9427 - val_loss: 0.9516 - val_acc: 0.7200
# Epoch 27/40
# 7221/7221 [==============================] - 16s 2ms/sample - loss: 0.1719 - acc: 0.9403 - val_loss: 0.9154 - val_acc: 0.7545
# Epoch 28/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.1488 - acc: 0.9542 - val_loss: 0.8169 - val_acc: 0.7725
# Epoch 29/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.1554 - acc: 0.9470 - val_loss: 0.8574 - val_acc: 0.7702
# Epoch 30/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.1463 - acc: 0.9532 - val_loss: 0.9869 - val_acc: 0.7443
# Epoch 31/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.1450 - acc: 0.9511 - val_loss: 0.8790 - val_acc: 0.7514
# Epoch 32/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.1408 - acc: 0.9503 - val_loss: 0.8839 - val_acc: 0.7561
# Epoch 33/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.1200 - acc: 0.9600 - val_loss: 0.9669 - val_acc: 0.7561
# Epoch 34/40
# 7221/7221 [==============================] - 16s 2ms/sample - loss: 0.1224 - acc: 0.9596 - val_loss: 0.9116 - val_acc: 0.7647
# Epoch 35/40
# 7221/7221 [==============================] - 16s 2ms/sample - loss: 0.1171 - acc: 0.9591 - val_loss: 1.0224 - val_acc: 0.7506
# Epoch 36/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.1148 - acc: 0.9623 - val_loss: 1.0449 - val_acc: 0.7286
# Epoch 37/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.1093 - acc: 0.9641 - val_loss: 1.1559 - val_acc: 0.7145
# Epoch 38/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.0981 - acc: 0.9686 - val_loss: 0.9983 - val_acc: 0.7506
# Epoch 39/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.1007 - acc: 0.9675 - val_loss: 0.9022 - val_acc: 0.7608
# Epoch 40/40
# 7221/7221 [==============================] - 15s 2ms/sample - loss: 0.0928 - acc: 0.9726 - val_loss: 0.8853 - val_acc: 0.7725
# 1500/1500 - 0s - loss: 1.0660 - acc: 0.7600
#
# Test accuracy: 0.76
# Target: 1, Predicted label: [1]
